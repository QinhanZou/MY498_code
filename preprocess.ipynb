# %%
import pandas as pd

# %%
# read all those Excel files as a DataFrame
# data/savedrecs (0).xls - savedrecs (19).xls
df = pd.DataFrame()
for i in range(20):
    df = pd.concat([df, pd.read_excel(f'data/savedrecs ({i}).xls')])

# %%
# how many publications in total?
print(f"Total number of publications: {df.shape[0]}")
# Out:
# Total number of publications: 19652

# %%
# add a new column as index
df['index'] = range(df.shape[0])
df = df.set_index('index')

# %%
# get all the column names
df.columns
# Out:
# Index(['Publication Type', 'Authors', 'Book Authors', 'Book Editors',
#        'Book Group Authors', 'Author Full Names', 'Book Author Full Names',
#        'Group Authors', 'Article Title', 'Source Title', 'Book Series Title',
#        'Book Series Subtitle', 'Language', 'Document Type', 'Conference Title',
#        'Conference Date', 'Conference Location', 'Conference Sponsor',
#        'Conference Host', 'Author Keywords', 'Keywords Plus', 'Abstract',
#        'Addresses', 'Affiliations', 'Reprint Addresses', 'Email Addresses',
#        'Researcher Ids', 'ORCIDs', 'Funding Orgs', 'Funding Name Preferred',
#        'Funding Text', 'Cited References', 'Cited Reference Count',
#        'Times Cited, WoS Core', 'Times Cited, All Databases',
#        '180 Day Usage Count', 'Since 2013 Usage Count', 'Publisher',
#        'Publisher City', 'Publisher Address', 'ISSN', 'eISSN', 'ISBN',
#        'Journal Abbreviation', 'Journal ISO Abbreviation', 'Publication Date',
#        'Publication Year', 'Volume', 'Issue', 'Part Number', 'Supplement',
#        'Special Issue', 'Meeting Abstract', 'Start Page', 'End Page',
#        'Article Number', 'DOI', 'DOI Link', 'Book DOI', 'Early Access Date',
#        'Number of Pages', 'WoS Categories', 'Web of Science Index',
#        'Research Areas', 'IDS Number', 'Pubmed Id', 'Open Access Designations',
#        'Highly Cited Status', 'Hot Paper Status', 'Date of Export',
#        'UT (Unique WOS ID)', 'Web of Science Record'],
#       dtype='object')

# %% [markdown]
# # 1. remove duplicated publications

# %%
# any duplicated publications?
print(f"Number of duplicated publications: {df.duplicated().sum()}")
# Out:
# Number of duplicated publications: 0

# %%
# any publications without Article Title?
print(f"Number of publications without Article Title: {df['Article Title'].isnull().sum()}")
# Out:
# Number of publications without Article Title: 0

# %%
# how many publications have same Article Title?
print(f"Number of publications with same Article Title: {df.duplicated('Article Title').sum()}")
# Out:
# Number of publications with same Article Title: 23

# %%
# print all the publications having same Article Title
df[df.duplicated(subset='Article Title', keep=False)].sort_values(by='Article Title')
# Out:
#       Publication Type                                            Authors  \
# index
# 1932                 J  Gkontzis, AF; Kotsiantis, S; Panagiotakopoulos...
# 1971                 J  Gkontzis, A; Kotsiantis, S; Panagiotakopoulos,...
# 14387                J                    Ceh, M; Smole, D; Podobnikar, T
# 14368                J                    Ceh, M; Smole, D; Podobnikar, T
# 9123                 J     Buckley, P; Doyle, E; McCarthy, B; Gilligan, R
# 9066                 J     Buckley, P; Doyle, E; McCarthy, B; Gilligan, R
# 9502                 J                                            Dhar, V
# 9520                 J                                            Dhar, V
# 7533                 J  Tzougas, G; Dang, V; John, A; Kroustalis, S; D...
# 7559                 J  Tzougas, G; Dang, VT; John, A; Kroustalis, S; ...
# 10633                J                   Kulkarni, H; Joshi, P; Chande, P
# 10616                J                   Kulkarni, H; Joshi, P; Chande, P
# 5965                 J  Cherkaoui, N; El Handri, K; Tanoga, MDY; El Ha...
# 6043                 J  Cherkaoui, N; El Handri, K; El Hassani, Y; Err...
# 13896                J  Nazar, R; Renau, I; Acosta, N; Robledo, H; Sol...
# 13868                J  Nazar, R; Renau, I; Acosta, N; Robledo, H; Sol...
# 10236                J       Magalhaes, IAL; de Carvalho, OA Jr; Sano, EE
# 10561                J           Magalhaes, IAL; Junior, OAD Jr; Sano, EE
# 17783                J           Yoganarasimhan, H; Barzegary, E; Pani, A
# 17787                J           Yoganarasimhan, H; Barzegary, E; Pani, A
# 16293                J                                       Piramuthu, S
# 16012                C                                       Piramuthu, S
# 16892                J                              Abeza, J; Gretchen, E
# 16873                J                             Abeza', J; Gretchen, E
# 9973                 J                              Casey, AJ; Niblett, A
# 13429                J                                          Alarie, B
# 8060                 J                                           Yoon, AH
# 4126                 J                                          Reddy, MS
# 3644                 J                                          Reddy, MS
# 931                  J        Subrahmanyam, CM; Satpathy, S; Satpathy, SK
# 924                  J        Subrahmanyam, CM; Satpathy, S; Satpathy, SK
# 3636                 J                                           Swamy, G
# 3657                 J                                           Swamy, G
# 3622                 J            Srinivas, N; Suryanarayana, D; Babu, BH
# 138                  J                             Simsek, M; Kesilmis, I
# 136                  J                             Simsek, M; Kesilmis, I
# 13741                J  Kim, VNP; Conti, DD; Gonzalez, EDRS; da Silva, LF
# 13728                J  Kim, VNP; Conti, DD; Gonzalez, EDRS; da Silva, LF
# 13697                J  Kim, VNP; Conti, DD; Gonzalez, EDRS; da Silva, LF
# 16831                J  Keeley, AR; Matsumoto, K; Tanaka, K; Sugiawan,...
# 16832                J  Keeley, AR; Matsumoto, K; Tanaka, K; Sugiawan,...
# 14540                J                                       Li, H; Li, C
# 15006                C                                       Li, C; Li, H
#
#       Book Authors Book Editors Book Group Authors  \
# index
# 1932           NaN          NaN                NaN
# 1971           NaN          NaN                NaN
# 14387          NaN          NaN                NaN
# 14368          NaN          NaN                NaN
# 9123           NaN          NaN                NaN
# 9066           NaN          NaN                NaN
# 9502           NaN          NaN                NaN
# 9520           NaN          NaN                NaN
# 7533           NaN          NaN                NaN
# 7559           NaN          NaN                NaN
# 10633          NaN          NaN                NaN
# 10616          NaN          NaN                NaN
# 5965           NaN          NaN                NaN
# 6043           NaN          NaN                NaN
# 13896          NaN          NaN                NaN
# 13868          NaN          NaN                NaN
# 10236          NaN          NaN                NaN
# 10561          NaN          NaN                NaN
# 17783          NaN          NaN                NaN
# 17787          NaN          NaN                NaN
# 16293          NaN          NaN                NaN
# 16012          NaN     Dolk, DR                NaN
# 16892          NaN          NaN                NaN
# 16873          NaN          NaN                NaN
# 9973           NaN          NaN                NaN
# 13429          NaN          NaN                NaN
# 8060           NaN          NaN                NaN
# 4126           NaN          NaN                NaN
# 3644           NaN          NaN                NaN
# 931            NaN          NaN                NaN
# 924            NaN          NaN                NaN
# 3636           NaN          NaN                NaN
# 3657           NaN          NaN                NaN
# 3622           NaN          NaN                NaN
# 138            NaN          NaN                NaN
# 136            NaN          NaN                NaN
# 13741          NaN          NaN                NaN
# 13728          NaN          NaN                NaN
# 13697          NaN          NaN                NaN
# 16831          NaN          NaN                NaN
# 16832          NaN          NaN                NaN
# 14540          NaN          NaN                NaN
# 15006          NaN          NaN                ACL
#
#                                        Author Full Names  \
# index
# 1932   Gkontzis, Andreas F.; Kotsiantis, Sotiris; Pan...
# 1971   Gkontzis, Andreas; Kotsiantis, S.; Panagiotako...
# 14387       Ceh, Marjan; Smole, Domen; Podobnikar, Tomaz
# 14368       Ceh, Marjan; Smole, Domen; Podobnikar, Tomaz
# 9123   Buckley, Patrick; Doyle, Elaine; McCarthy, Bre...
# 9066   Buckley, Patrick; Doyle, Elaine; McCarthy, Bre...
# 9502                                        Dhar, Vasant
# 9520                                        Dhar, Vasant
# 7533   Tzougas, George; Dang, Viet; John, Asif; Krous...
# 7559   Tzougas, George; Dang, Viet; John, Asif; Krous...
# 10633  Kulkarni, Hrishikesh; Joshi, Prachi; Chande, P...
# 10616  Kulkarni, Hrishikesh; Joshi, Prachi; Chande, P...
# 5965   Cherkaoui, Nabil; El Handri, Kaoutar; Tanoga, ...
# 6043   Cherkaoui, Nabil; El Handri, Kaoutar; El Hassa...
# 13896  Nazar, Rogelio; Renau, Irene; Acosta, Nicolas;...
# 13868  Nazar, Rogelio; Renau, Irene; Acosta, Nicolas;...
# 10236  Magalhaes, Ivo Augusto Lopes; de Carvalho, Osm...
# 10561  Magalhaes, Ivo Augusto Lopes; de Carvalho Juni...
# 17783  Yoganarasimhan, Hema; Barzegary, Ebrahim; Pani...
# 17787  Yoganarasimhan, Hema; Barzegary, Ebrahim; Pani...
# 16293                                       Piramuthu, S
# 16012                                       Piramuthu, S
# 16892                      Abeza, Jimmy; Gretchen, Ellen
# 16873                     Abeza', Jimmy; Gretchen, Ellen
# 9973                 Casey, Anthony J.; Niblett, Anthony
# 13429                                   Alarie, Benjamin
# 8060                                     Yoon, Albert H.
# 4126                                  Reddy, M. Sivakoti
# 3644                                  Reddy, M. Sivakoti
# 931    Subrahmanyam, Challa Maruthy; Satpathy, Sarita...
# 924    Subrahmanyam, Challa Maruthy; Satpathy, Sarita...
# 3636                                           Swamy, G.
# 3657                                           Swamy, G.
# 3622   Srinivas, N.; Suryanarayana, Vadhri; Babu, B. ...
# 138                       Simsek, Mehmet; Kesilmis, Inci
# 136                       Simsek, Mehmet; Kesilmis, Inci
# 13741  Kim, Victor Natan Pinheiro; Conti, Diego de Me...
# 13728  Pinheiro Kim, Victor Natan; Conti, Diego de Me...
# 13697  Kim, Victor Natan Pinheiro; Conti, Diego de Me...
# 16831  Keeley, Alexander Ryota; Matsumoto, Ken'ichi; ...
# 16832  Keeley, Alexander Ryota; Matsumoto, Ken'ichi; ...
# 14540                                       Li, H; Li, C
# 15006                                       Li, C; Li, H
#
#       Book Author Full Names Group Authors  \
# index
# 1932                     NaN           NaN
# 1971                     NaN           NaN
# 14387                    NaN           NaN
# 14368                    NaN           NaN
# 9123                     NaN           NaN
# 9066                     NaN           NaN
# 9502                     NaN           NaN
# 9520                     NaN           NaN
# 7533                     NaN           NaN
# 7559                     NaN           NaN
# 10633                    NaN           NaN
# 10616                    NaN           NaN
# 5965                     NaN           NaN
# 6043                     NaN           NaN
# 13896                    NaN           NaN
# 13868                    NaN           NaN
# 10236                    NaN           NaN
# 10561                    NaN           NaN
# 17783                    NaN           NaN
# 17787                    NaN           NaN
# 16293                    NaN           NaN
# 16012                    NaN           NaN
# 16892                    NaN           NaN
# 16873                    NaN           NaN
# 9973                     NaN           NaN
# 13429                    NaN           NaN
# 8060                     NaN           NaN
# 4126                     NaN           NaN
# 3644                     NaN           NaN
# 931                      NaN           NaN
# 924                      NaN           NaN
# 3636                     NaN           NaN
# 3657                     NaN           NaN
# 3622                     NaN           NaN
# 138                      NaN           NaN
# 136                      NaN           NaN
# 13741                    NaN           NaN
# 13728                    NaN           NaN
# 13697                    NaN           NaN
# 16831                    NaN           NaN
# 16832                    NaN           NaN
# 14540                    NaN           NaN
# 15006                    NaN           NaN
#
#                                            Article Title  \
# index
# 1932   A predictive analytics framework as a counterm...
# 1971   A predictive analytics framework as a counterm...
# 14387  APPLICATION OF UNIVERSAL ONTOLOGY OF GEOGRAPHI...
# 14368  APPLICATION OF UNIVERSAL ONTOLOGY OF GEOGRAPHI...
# 9123    ARTIFICIAL INTELLIGENCE AND THE TAX PRACTITIONER
# 9066    ARTIFICIAL INTELLIGENCE AND THE TAX PRACTITIONER
# 9502   BIAS AND NOISE IN HUMANS & AI: WHEN TO TRUST H...
# 9520   BIAS AND NOISE IN HUMANS & AI: WHEN TO TRUST H...
# 7533   CLASSIFICATION OF CLIMATE-RELATED INSURANCE CL...
# 7559   CLASSIFICATION OF CLIMATE-RELATED INSURANCE CL...
# 10633  Computational Psychology to Embed Emotions int...
# 10616  Computational Psychology to Embed Emotions int...
# 5965   Consumer Behaviour: Analysing Marketing Campai...
# 6043   Consumer Behaviour: Analysing Marketing Campai...
# 13896  Corpus-Based Methods for Recognizing the Gende...
# 13868  Corpus-Based Methods for Recognizing the Gende...
# 10236  DELIMITATION OF FLOODED AREAS BASED ON SENTINE...
# 10561  DELIMITATION OF FLOODED AREAS BASED ON SENTINE...
# 17783       Design and Evaluation of Optimal Free Trials
# 17787       Design and Evaluation of Optimal Free Trials
# 16293  Evaluating feature selection methods for learn...
# 16012  Evaluating feature selection methods for learn...
# 16892  Exploring the Impact of IT-Enabled Innovations...
# 16873  Exploring the Impact of IT-Enabled Innovations...
# 9973   FOCUS FEATURE: ARTIFICIAL INTELLIGENCE, BIG DA...
# 13429  FOCUS FEATURE: ARTIFICIAL INTELLIGENCE, BIG DA...
# 8060   FOCUS FEATURE: ARTIFICIAL INTELLIGENCE, BIG DA...
# 4126   IMPACT OF SOCIAL NETWORK ADVERTISEMENTS OF WEL...
# 3644   IMPACT OF SOCIAL NETWORK ADVERTISEMENTS OF WEL...
# 931    MACHINE LEARNING APPROACH ON INDIAN HEALTHCARE...
# 924    MACHINE LEARNING APPROACH ON INDIAN HEALTHCARE...
# 3636      Machine Learning based Face Recognition System
# 3657      Machine Learning based Face Recognition System
# 3622      Machine Learning based Face Recognition System
# 138    Predicting athletic performance from physiolog...
# 136    Predicting athletic performance from physiolog...
# 13741  THE INTERRELATION BETWEEN INDUSTRY 4.0 AND CIR...
# 13728  THE INTERRELATION BETWEEN INDUSTRY 4.0 AND CIR...
# 13697  THE INTERRELATION BETWEEN INDUSTRY 4.0 AND CIR...
# 16831  The Impact of Renewable Energy Generation on t...
# 16832  The Impact of Renewable Energy Generation on t...
# 14540  Word translation disambiguation using bilingua...
# 15006  Word translation disambiguation using bilingua...
#
#                                             Source Title  ...  \
# index                                                     ...
# 1932                   INTERACTIVE LEARNING ENVIRONMENTS  ...
# 1971                   INTERACTIVE LEARNING ENVIRONMENTS  ...
# 14387                                  GEODETSKI VESTNIK  ...
# 14368                                  GEODETSKI VESTNIK  ...
# 9123                       JOURNAL OF TAX ADMINISTRATION  ...
# 9066                       JOURNAL OF TAX ADMINISTRATION  ...
# 9502                    JOURNAL OF INVESTMENT MANAGEMENT  ...
# 9520                    JOURNAL OF INVESTMENT MANAGEMENT  ...
# 7533         ANALES DEL INSTITUTO DE ACTUARIOS ESPANOLES  ...
# 7559         ANALES DEL INSTITUTO DE ACTUARIOS ESPANOLES  ...
# 10633            INDIAN JOURNAL OF PSYCHOLOGICAL SCIENCE  ...
# 10616            INDIAN JOURNAL OF PSYCHOLOGICAL SCIENCE  ...
# 5965             MARKETING AND MANAGEMENT OF INNOVATIONS  ...
# 6043             MARKETING AND MANAGEMENT OF INNOVATIONS  ...
# 13896                      NAMES-A JOURNAL OF ONOMASTICS  ...
# 13868                      NAMES-A JOURNAL OF ONOMASTICS  ...
# 10236         FINISTERRA-REVISTA PORTUGUESA DE GEOGRAFIA  ...
# 10561         FINISTERRA-REVISTA PORTUGUESA DE GEOGRAFIA  ...
# 17783                                 MANAGEMENT SCIENCE  ...
# 17787                                 MANAGEMENT SCIENCE  ...
# 16293           EUROPEAN JOURNAL OF OPERATIONAL RESEARCH  ...
# 16012  PROCEEDINGS OF THE THIRTY-FIRST HAWAII INTERNA...  ...
# 16892                  REVISTA DE PSICOLOGIA DEL DEPORTE  ...
# 16873                  REVISTA DE PSICOLOGIA DEL DEPORTE  ...
# 9973                   UNIVERSITY OF TORONTO LAW JOURNAL  ...
# 13429                  UNIVERSITY OF TORONTO LAW JOURNAL  ...
# 8060                   UNIVERSITY OF TORONTO LAW JOURNAL  ...
# 4126   INTERNATIONAL JOURNAL OF EARLY CHILDHOOD SPECI...  ...
# 3644   INTERNATIONAL JOURNAL OF EARLY CHILDHOOD SPECI...  ...
# 931    INTERNATIONAL JOURNAL OF EARLY CHILDHOOD SPECI...  ...
# 924    INTERNATIONAL JOURNAL OF EARLY CHILDHOOD SPECI...  ...
# 3636   INTERNATIONAL JOURNAL OF EARLY CHILDHOOD SPECI...  ...
# 3657   INTERNATIONAL JOURNAL OF EARLY CHILDHOOD SPECI...  ...
# 3622   INTERNATIONAL JOURNAL OF EARLY CHILDHOOD SPECI...  ...
# 138                          JOURNAL OF SPORTS ANALYTICS  ...
# 136                          JOURNAL OF SPORTS ANALYTICS  ...
# 13741  REVISTA GESTAO & TECNOLOGIA-JOURNAL OF MANAGEM...  ...
# 13728  REVISTA GESTAO & TECNOLOGIA-JOURNAL OF MANAGEM...  ...
# 13697  REVISTA GESTAO & TECNOLOGIA-JOURNAL OF MANAGEM...  ...
# 16831                                     ENERGY JOURNAL  ...
# 16832                                     ENERGY JOURNAL  ...
# 14540                          COMPUTATIONAL LINGUISTICS  ...
# 15006  40TH ANNUAL MEETING OF THE ASSOCIATION FOR COM...  ...
#
#                                     Web of Science Index  \
# index
# 1932                Social Science Citation Index (SSCI)
# 1971                Social Science Citation Index (SSCI)
# 14387               Social Science Citation Index (SSCI)
# 14368               Social Science Citation Index (SSCI)
# 9123              Emerging Sources Citation Index (ESCI)
# 9066              Emerging Sources Citation Index (ESCI)
# 9502              Emerging Sources Citation Index (ESCI)
# 9520              Emerging Sources Citation Index (ESCI)
# 7533              Emerging Sources Citation Index (ESCI)
# 7559              Emerging Sources Citation Index (ESCI)
# 10633             Emerging Sources Citation Index (ESCI)
# 10616             Emerging Sources Citation Index (ESCI)
# 5965              Emerging Sources Citation Index (ESCI)
# 6043              Emerging Sources Citation Index (ESCI)
# 13896  Social Science Citation Index (SSCI); Arts & H...
# 13868  Social Science Citation Index (SSCI); Arts & H...
# 10236             Emerging Sources Citation Index (ESCI)
# 10561             Emerging Sources Citation Index (ESCI)
# 17783  Science Citation Index Expanded (SCI-EXPANDED)...
# 17787  Science Citation Index Expanded (SCI-EXPANDED)...
# 16293     Science Citation Index Expanded (SCI-EXPANDED)
# 16012  Conference Proceedings Citation Index - Scienc...
# 16892               Social Science Citation Index (SSCI)
# 16873               Social Science Citation Index (SSCI)
# 9973                Social Science Citation Index (SSCI)
# 13429               Social Science Citation Index (SSCI)
# 8060                Social Science Citation Index (SSCI)
# 4126              Emerging Sources Citation Index (ESCI)
# 3644              Emerging Sources Citation Index (ESCI)
# 931               Emerging Sources Citation Index (ESCI)
# 924               Emerging Sources Citation Index (ESCI)
# 3636              Emerging Sources Citation Index (ESCI)
# 3657              Emerging Sources Citation Index (ESCI)
# 3622              Emerging Sources Citation Index (ESCI)
# 138               Emerging Sources Citation Index (ESCI)
# 136               Emerging Sources Citation Index (ESCI)
# 13741             Emerging Sources Citation Index (ESCI)
# 13728             Emerging Sources Citation Index (ESCI)
# 13697             Emerging Sources Citation Index (ESCI)
# 16831  Science Citation Index Expanded (SCI-EXPANDED)...
# 16832  Science Citation Index Expanded (SCI-EXPANDED)...
# 14540  Science Citation Index Expanded (SCI-EXPANDED)...
# 15006  Conference Proceedings Citation Index - Scienc...
#
#                                           Research Areas IDS Number Pubmed Id  \
# index
# 1932                    Education & Educational Research      2L4KF       NaN
# 1971                    Education & Educational Research      ZW7ZH       NaN
# 14387                                          Geography      921SR       NaN
# 14368                                          Geography      921SR       NaN
# 9123                                Business & Economics      F1NT9       NaN
# 9066                                Business & Economics      D8GP7       NaN
# 9502                                Business & Economics      8O6MN       NaN
# 9520                                Business & Economics      8T0ZZ       NaN
# 7533                                Business & Economics      G9YH4       NaN
# 7559                                Business & Economics      7M9UZ       NaN
# 10633                                         Psychology      5T1NB       NaN
# 10616                                         Psychology      Q0DG6       NaN
# 5965                                Business & Economics      YQ5M0       NaN
# 6043                                Business & Economics      XN5U1       NaN
# 13896                                        Linguistics      OU9DK       NaN
# 13868                                        Linguistics      UC1EB       NaN
# 10236                                          Geography      X3BP3       NaN
# 10561                                          Geography      X3BP3       NaN
# 17783  Business & Economics; Operations Research & Ma...      3U2LX       NaN
# 17787  Business & Economics; Operations Research & Ma...      DL8O2       NaN
# 16293  Business & Economics; Operations Research & Ma...      805DF       NaN
# 16012  Computer Science; Information Science & Librar...      BK43G       NaN
# 16892                                         Psychology      U8XX5       NaN
# 16873                                         Psychology      U8XX5       NaN
# 9973                                    Government & Law      EC3GC       NaN
# 13429                                   Government & Law      EC3GC       NaN
# 8060                                    Government & Law      EC3GC       NaN
# 4126                    Education & Educational Research      2G2QV       NaN
# 3644                    Education & Educational Research      2G2QV       NaN
# 931                     Education & Educational Research      3K6UR       NaN
# 924                     Education & Educational Research      3O8XA       NaN
# 3636                    Education & Educational Research      1U4XO       NaN
# 3657                    Education & Educational Research      1U4XO       NaN
# 3622                    Education & Educational Research      1A6DB       NaN
# 138    Social Sciences - Other Topics; Mathematical M...      7O9PN       NaN
# 136    Social Sciences - Other Topics; Mathematical M...      4R2QT       NaN
# 13741                               Business & Economics      H3YC4       NaN
# 13728                               Business & Economics      8T2DQ       NaN
# 13697                               Business & Economics      H3YC4       NaN
# 16831  Business & Economics; Energy & Fuels; Environm...      VN6WI       NaN
# 16832  Business & Economics; Energy & Fuels; Environm...      OV5IL       NaN
# 14540                      Computer Science; Linguistics      810ZA       NaN
# 15006         Computer Science; Linguistics; Mathematics      BAP07       NaN
#
#       Open Access Designations Highly Cited Status Hot Paper Status  \
# index
# 1932                       NaN                 NaN              NaN
# 1971                       NaN                 NaN              NaN
# 14387                      NaN                 NaN              NaN
# 14368                      NaN                 NaN              NaN
# 9123                       NaN                 NaN              NaN
# 9066                       NaN                 NaN              NaN
# 9502                       NaN                 NaN              NaN
# 9520                       NaN                 NaN              NaN
# 7533                    hybrid                 NaN              NaN
# 7559                       NaN                 NaN              NaN
# 10633                      NaN                 NaN              NaN
# 10616                      NaN                 NaN              NaN
# 5965                       NaN                 NaN              NaN
# 6043                       NaN                 NaN              NaN
# 13896                      NaN                 NaN              NaN
# 13868                     gold                 NaN              NaN
# 10236                      NaN                 NaN              NaN
# 10561                      NaN                 NaN              NaN
# 17783                      NaN                 NaN              NaN
# 17787                      NaN                 NaN              NaN
# 16293                      NaN                 NaN              NaN
# 16012                      NaN                 NaN              NaN
# 16892                      NaN                 NaN              NaN
# 16873                      NaN                 NaN              NaN
# 9973                       NaN                 NaN              NaN
# 13429                      NaN                 NaN              NaN
# 8060                       NaN                 NaN              NaN
# 4126                       NaN                 NaN              NaN
# 3644                       NaN                 NaN              NaN
# 931                        NaN                 NaN              NaN
# 924                        NaN                 NaN              NaN
# 3636                       NaN                 NaN              NaN
# 3657                       NaN                 NaN              NaN
# 3622                       NaN                 NaN              NaN
# 138                       gold                 NaN              NaN
# 136                       gold                 NaN              NaN
# 13741                      NaN                 NaN              NaN
# 13728                      NaN                 NaN              NaN
# 13697                      NaN                 NaN              NaN
# 16831  Bronze, Green Submitted                 NaN              NaN
# 16832          Green Submitted                 NaN              NaN
# 14540                   hybrid                 NaN              NaN
# 15006                      NaN                 NaN              NaN
#
#       Date of Export   UT (Unique WOS ID) Web of Science Record
# index
# 1932      2024-07-30  WOS:000504961700001                     0
# 1971      2024-07-30  WOS:000492543300001                     0
# 14387     2024-07-30  WOS:000302498300006                     0
# 14368     2024-07-30  WOS:000302498300005                     0
# 9123      2024-07-30  WOS:000980091200002                     0
# 9066      2024-07-30  WOS:000971059900002                     0
# 9502      2024-07-30  WOS:000925949200006                     0
# 9520      2024-07-30  WOS:000929000200006                     0
# 7533      2024-07-30  WOS:000992620600001                     0
# 7559      2024-07-30  WOS:000906995700007                     0
# 10633     2024-07-30  WOS:000875641400003                     0
# 10616     2024-07-30  WOS:001054293300003                     0
# 5965      2024-07-30  WOS:001269961700001                     0
# 6043      2024-07-30  WOS:001262385500009                     0
# 13896     2024-07-30  WOS:000591823500001                     0
# 13868     2024-07-30  WOS:000686275700003                     0
# 10236     2024-07-30  WOS:001097243200004                     0
# 10561     2024-07-30  WOS:001097243200003                     0
# 17783     2024-07-30  WOS:000840807200001                     0
# 17787     2024-07-30  WOS:001132292000001                     0
# 16293     2024-07-30  WOS:000220346300015                     0
# 16012     2024-07-30  WOS:000072157400035                     0
# 16892     2024-07-30  WOS:001087586000002                     0
# 16873     2024-07-30  WOS:001087586000001                     0
# 9973      2024-07-30  WOS:000388013100002                     0
# 13429     2024-07-30  WOS:000388013100003                     0
# 8060      2024-07-30  WOS:000388013100004                     0
# 4126      2024-07-30  WOS:000813443800009                     0
# 3644      2024-07-30  WOS:000813443800008                     0
# 931       2024-07-30  WOS:000834211600031                     0
# 924       2024-07-30  WOS:000837116700001                     0
# 3636      2024-07-30  WOS:000805417800009                     0
# 3657      2024-07-30  WOS:000805417800032                     0
# 3622      2024-07-30  WOS:000791844000024                     0
# 138       2024-07-30  WOS:000908347000005                     0
# 136       2024-07-30  WOS:000856614500005                     0
# 13741     2024-07-30  WOS:000995345400016                     0
# 13728     2024-07-30  WOS:000929078100013                     0
# 13697     2024-07-30  WOS:000995345400017                     0
# 16831     2024-07-30  WOS:001184587000005                     0
# 16832     2024-07-30  WOS:000592243300007                     0
# 14540     2024-07-30  WOS:000220741000001                     0
# 15006     2024-07-30  WOS:000223096700044                     0
#
# [43 rows x 72 columns]

# %%
# drop the duplicated publications

# 1. keep the latest published one
# drop 15006,16832,16012,17783,13896,10633,1971
df = df.drop([15006,16832,16012,17783,13896,10633,1971])

# 2. keep written in English
# drop 13728,13697,14368
df = df.drop([13728,13697,14368])

# drop 9123,9520,7559,6043,10561,16892,4126,931,3657,3636,138
df = df.drop([9123,9520,7559,6043,10561,16892,4126,931,3657,3636,138])

df[df.duplicated(subset='Article Title', keep=False)].sort_values(by='Article Title')
# Out:
#       Publication Type                Authors Book Authors Book Editors  \
# index
# 8060                 J               Yoon, AH          NaN          NaN
# 9973                 J  Casey, AJ; Niblett, A          NaN          NaN
# 13429                J              Alarie, B          NaN          NaN
#
#       Book Group Authors                    Author Full Names  \
# index
# 8060                 NaN                      Yoon, Albert H.
# 9973                 NaN  Casey, Anthony J.; Niblett, Anthony
# 13429                NaN                     Alarie, Benjamin
#
#       Book Author Full Names Group Authors  \
# index
# 8060                     NaN           NaN
# 9973                     NaN           NaN
# 13429                    NaN           NaN
#
#                                            Article Title  \
# index
# 8060   FOCUS FEATURE: ARTIFICIAL INTELLIGENCE, BIG DA...
# 9973   FOCUS FEATURE: ARTIFICIAL INTELLIGENCE, BIG DA...
# 13429  FOCUS FEATURE: ARTIFICIAL INTELLIGENCE, BIG DA...
#
#                             Source Title  ...  \
# index                                     ...
# 8060   UNIVERSITY OF TORONTO LAW JOURNAL  ...
# 9973   UNIVERSITY OF TORONTO LAW JOURNAL  ...
# 13429  UNIVERSITY OF TORONTO LAW JOURNAL  ...
#
#                        Web of Science Index    Research Areas IDS Number  \
# index
# 8060   Social Science Citation Index (SSCI)  Government & Law      EC3GC
# 9973   Social Science Citation Index (SSCI)  Government & Law      EC3GC
# 13429  Social Science Citation Index (SSCI)  Government & Law      EC3GC
#
#       Pubmed Id Open Access Designations Highly Cited Status Hot Paper Status  \
# index
# 8060        NaN                      NaN                 NaN              NaN
# 9973        NaN                      NaN                 NaN              NaN
# 13429       NaN                      NaN                 NaN              NaN
#
#       Date of Export   UT (Unique WOS ID) Web of Science Record
# index
# 8060      2024-07-30  WOS:000388013100004                     0
# 9973      2024-07-30  WOS:000388013100002                     0
# 13429     2024-07-30  WOS:000388013100003                     0
#
# [3 rows x 72 columns]

# %%
print(f"Total number of publications: {df.shape[0]}")
# Out:
# Total number of publications: 19631

# %% [markdown]
# # 2. check language for text material

# %%
# check if all the abstracts are in English
# print the abstract when it is not in English and not missing
# from langdetect import detect

# for i in range(df.shape[0]):
#     try:
#         if df['Abstract'].notnull()[i] and detect(df['Abstract'][i]) != 'en':
#             print(df['Abstract'][i], '\n')
#     except:
#         pass

# %%
# check if Author Keywords are in English
# import langid

# for i in range(df.shape[0]):
#     try:
#         if df['Author Keywords'].notnull()[i] and langid.classify(df['Author Keywords'][i])[0] != 'en':
#             print(df['Author Keywords'][i], '\n')
#     except:
#         pass

# %% [markdown]
# # 3. group those publications

# %%
# any publications without Publication Year
print(f"Number of publications without Publication Year: {df['Publication Year'].isnull().sum()}")
# Out:
# Number of publications without Publication Year: 0

# %%
# how many publications each year?
df['Publication Year'].value_counts().sort_index()
# Out:
# 1973       1
# 1986       2
# 1987       2
# 1988       2
# 1989       3
# 1990       2
# 1991       5
# 1992       6
# 1993       3
# 1994       8
# 1995      15
# 1996       9
# 1997      14
# 1998      19
# 1999       7
# 2000      23
# 2001      25
# 2002      24
# 2003      41
# 2004      29
# 2005      33
# 2006      44
# 2007      60
# 2008     125
# 2009      90
# 2010     125
# 2011      75
# 2012     133
# 2013     109
# 2014     245
# 2015     248
# 2016     492
# 2017     515
# 2018     885
# 2019    1513
# 2020    2172
# 2021    2806
# 2022    3359
# 2023    3705
# 2024    2657
# Name: Publication Year, dtype: int64

# %%
# how many publications each decade?
df['Publication Year'] = df['Publication Year'].astype(int)
df['Decade'] = df['Publication Year'] // 10 * 10
df['Decade'].value_counts().sort_index()
# Out:
# 1970        1
# 1980        9
# 1990       88
# 2000      494
# 2010     4340
# 2020    14699
# Name: Decade, dtype: int64

# %%
# group 1: 1970-2009
# group 2: 2010-2014
# group 3: 2015-2019
# group 4: 2020
# group 5: 2021
# group 6: 2022
# group 7: 2023
# group 8: 2024
# count the number of publications in each group
df['Group'] = 1
df.loc[df['Publication Year'] >= 2010, 'Group'] = 2
df.loc[df['Publication Year'] >= 2015, 'Group'] = 3
df.loc[df['Publication Year'] >= 2020, 'Group'] = 4
df.loc[df['Publication Year'] >= 2021, 'Group'] = 5
df.loc[df['Publication Year'] >= 2022, 'Group'] = 6
df.loc[df['Publication Year'] >= 2023, 'Group'] = 7
df.loc[df['Publication Year'] >= 2024, 'Group'] = 8
df['Group'].value_counts().sort_index()
# Out:
# 1     592
# 2     687
# 3    3653
# 4    2172
# 5    2806
# 6    3359
# 7    3705
# 8    2657
# Name: Group, dtype: int64

# %% [markdown]
# # 4. preprocess WoS Categories and Research Areas

# %%
# any publications without WoS Categories?
print(f"Number of publications without WoS Categories: {df['WoS Categories'].isnull().sum()}")
# any publications without Research Areas?
print(f"Number of publications without Research Areas: {df['Research Areas'].isnull().sum()}")
# Out:
# Number of publications without WoS Categories: 0
# Number of publications without Research Areas: 0

# %%
# split WoS Categories by ;
df['WoS Categories new'] = df['WoS Categories'].str.split(';')
# remove leading and trailing spaces
df['WoS Categories new'] = df['WoS Categories new'].apply(lambda x: [i.strip() for i in x])
# split Research Areas by ;
df['Research Areas new'] = df['Research Areas'].str.split(';')
# remove leading and trailing spaces
df['Research Areas new'] = df['Research Areas new'].apply(lambda x: [i.strip() for i in x])

# %%
# unique WoS Categories and sort by alphabetical order and save as a txt file
with open('output/WC/WoS_Categories.txt', 'w') as f:
    for item in sorted(set(df['WoS Categories new'].explode())):
        f.write("%s\n" % item)
# print the number of unique WoS Categories
print(f"Number of unique WoS Categories: {len(set(df['WoS Categories new'].explode()))}")
# Out:
# Number of unique WoS Categories: 166

# %%
# unique Research Areas and sort by alphabetical order and save as a txt file
with open('output/SU/Research_Areas.txt', 'w') as f:
    for item in sorted(set(df['Research Areas new'].explode())):
        f.write("%s\n" % item)
# print the number of unique Research Areas
print(f"Number of unique Research Areas: {len(set(df['Research Areas new'].explode()))}")
# Out:
# Number of unique Research Areas: 104

# %% [markdown]
# # 5. preprocess keywords

# %%
# any publications without Keywords Plus?
print(f"Number of publications without Keywords Plus: {df['Keywords Plus'].isnull().sum()}")
# Out:
# Number of publications without Keywords Plus: 5619

# %%
# split Keywords Plus by ;
df['Keywords Plus new'] = df['Keywords Plus'].str.split(';')
# fill missing values with empty list
df['Keywords Plus new'] = df['Keywords Plus new'].apply(lambda x: [] if type(x) != list else x)
# lower case and remove leading and trailing spaces
df['Keywords Plus new'] = df['Keywords Plus new'].apply(lambda x: [i.strip().lower() for i in x])

# %%
# replace all '-' with ' '
df['Keywords Plus new'] = df['Keywords Plus new'].apply(lambda x: [i.replace('-', ' ') for i in x])

# %%
# lemmalize Keywords Plus
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized_keywords = []

for keywords in df['Keywords Plus new'].values:
    lemmatized_list = []
    for keyword in keywords:
        words = keyword.split()
        lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
        lemmatized_keyword = ' '.join(lemmatized_words)
        lemmatized_list.append(lemmatized_keyword)
    lemmatized_keywords.append(lemmatized_list)

df['Keywords Plus lemmatized'] = lemmatized_keywords

# %%
# replace abbreviation with full name
# https://github.com/prajwalkhairnar/abbreviations_py
from abbreviations_py.textes.abbreviator import fix, update_abbreviations

new_mappings = {
    "ai": "artificial intelligence",
    "ml": "machine learning",
    "dl": "deep learning",
    "nlp": "natural language processing",
    "svm": "support vector machine",
    "ann": "artificial neural network",
    "cnn": "convolutional neural network",
    "rnn": "recurrent neural network",
    "lstm": "long short term memory",
    "gan": "generative adversarial network",
    "knn": "k nearest neighbors",
    "pca": "principal component analysis",
    "tsne": "t distributed stochastic neighbor embedding",
    "relu": "rectified linear unit",
    "mse": "mean squared error",
    "rmse": "root mean squared error",
    "mae": "mean absolute error",
    "r2": "coefficient of determination",
    "roc": "receiver operating characteristic",
    "rf": "random forest",
    "auc": "area under the curve",
    "sgd": "stochastic gradient descent",
    "adam": "adaptive moment estimation",
    "rbm": "restricted boltzmann machine",
    "dbn": "deep belief network",
    "svd": "singular value decomposition",
    "ae": "autoencoder",
    "vae": "variational autoencoder",
    "frmi": "functional magnetic resonance imaging",
    "llm": "latent linear model",
    "dnn": "deep neural network",
    "gi": "generative intelligence"
}

update_abbreviations(new_mappings)

df['Keywords Plus lemmatized'] = df['Keywords Plus lemmatized'].apply(lambda x: [fix(i) for i in x])

# %%
# show first 5 rows of Keywords Plus lemmatized and Keywords Plus
df[['Keywords Plus lemmatized', 'Keywords Plus']].head()
# Out:
#                                 Keywords Plus lemmatized  \
# index
# 0                                [banking fraud, system]
# 1                                          [woman, work]
# 2      [volatility, sample, jump, premium, model, rob...
# 3      [semiparametric regression model, incumbency a...
# 4      [independent component analysis, variable sele...
#
#                                            Keywords Plus
# index
# 0                                  BANKING FRAUD; SYSTEM
# 1                                            WOMEN; WORK
# 2      VOLATILITY; SAMPLE; JUMPS; PREMIUM; MODELS; RO...
# 3      SEMIPARAMETRIC REGRESSION-MODELS; INCUMBENCY A...
# 4      INDEPENDENT COMPONENT ANALYSIS; VARIABLE SELEC...

# %%
# unique Keywords Plus lemmatized and sort by alphabetical order and save as a txt file
with open('output/KP/Keywords_Plus.txt', 'w') as f:
    for item in sorted(set(df['Keywords Plus lemmatized'].explode().dropna())):
        f.write("%s\n" % item)
# print the number of unique Keywords Plus lemmatized
print(f"Number of unique Keywords Plus lemmatized: {len(set(df['Keywords Plus lemmatized'].explode()))}")
# Out:
# Number of unique Keywords Plus lemmatized: 15030

# %%
# any publications without Author Keywords?
# print(f"Number of publications without Author Keywords: {df['Author Keywords'].isnull().sum()}")

# %%
# split Author Keywords by ;
df['Author Keywords new'] = df['Author Keywords'].str.split(';')
# fill missing values with empty list
df['Author Keywords new'] = df['Author Keywords new'].apply(lambda x: [] if type(x) != list else x)
# lower case and remove leading and trailing spaces
df['Author Keywords new'] = df['Author Keywords new'].apply(lambda x: [i.strip().lower() for i in x])

# %%
# replace all '-' with ' '
df['Author Keywords new'] = df['Author Keywords new'].apply(lambda x: [i.replace('-', ' ') for i in x])

# %%
# delete () and the content inside
df['Author Keywords new'] = df['Author Keywords new'].apply(lambda x: [i.split('(')[0].strip() for i in x])
# delete words that have only one English letter
df['Author Keywords new'] = df['Author Keywords new'].apply(
    lambda x: [i for i in x if len([j for j in i if j.isalpha()]) > 1])
# delete puncutation '
df['Author Keywords new'] = df['Author Keywords new'].apply(lambda x: [i.replace("'", '') for i in x])

# %%
# lemmalize Author Keywords
lemmatized_keywords = []

for keywords in df['Author Keywords new'].values:
    lemmatized_list = []
    for keyword in keywords:
        words = keyword.split()
        lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
        lemmatized_keyword = ' '.join(lemmatized_words)
        lemmatized_list.append(lemmatized_keyword)
    lemmatized_keywords.append(lemmatized_list)

df['Author Keywords lemmatized'] = lemmatized_keywords

# %%
# replace abbreviation with full name
df['Author Keywords lemmatized'] = df['Author Keywords lemmatized'].apply(lambda x: [fix(i) for i in x])

# %%
# unique Author Keywords lemmatized and sort by alphabetical order and save as a txt file
with open('output/AK/Author_Keywords.txt', 'w') as f:
    for item in sorted(set(df['Author Keywords lemmatized'].explode().dropna())):
        f.write("%s\n" % item)
# print the number of unique Author Keywords lemmatized
print(f"Number of unique Author Keywords lemmatized: {len(set(df['Author Keywords lemmatized'].explode()))}")
# Out:
# Number of unique Author Keywords lemmatized: 36394

# %%
# any publications without Authors Keywords
print(f"Number of publications without Authors Keywords: {df['Author Keywords lemmatized'].apply(lambda x: len(x) == 0).sum()}")
# Out:
# Number of publications without Authors Keywords: 2327

# %%
# combine Author Keywords lemmatized and Keywords Plus lemmatized to All Keywords, remove duplicates
df['All Keywords'] = df['Author Keywords lemmatized'] + df['Keywords Plus lemmatized']
df['All Keywords'] = df['All Keywords'].apply(lambda x: list(set(x)))

# %%
# any publications without All Keywords?
print(f"Number of publications without All Keywords: {df['All Keywords'].apply(len).eq(0).sum()}")
# Out:
# Number of publications without All Keywords: 1115

# %% [markdown]
# # 6. find country information

# %%
# any publications without Addresses?
print(f"Number of publications without Addresses: {df['Addresses'].isnull().sum()}")
# Out:
# Number of publications without Addresses: 104

# %%
# split Addresses by ;
df['Addresses new'] = df['Addresses'].str.split(';')
# fill missing values with empty list
df['Addresses new'] = df['Addresses new'].apply(lambda x: [] if type(x) != list else x)
# remove leading and trailing spaces
df['Addresses new'] = df['Addresses new'].apply(lambda x: [i.strip() for i in x])

# %%
# only keep the last word of each address
df['Addresses new'] = df['Addresses new'].apply(lambda x: [i.split()[-1] for i in x])
df['Addresses new'].head()
# Out:
# index
# 0    [Switzerland, Switzerland, Switzerland, Switze...
# 1                  [Netherlands, Netherlands, England]
# 2                                        [Weijia, USA]
# 3                                           [USA, USA]
# 4                                   [Ireland, England]
# Name: Addresses new, dtype: object

# %%
# print addresses of 2
df['Addresses'][2]
# Out:
# '[Peng, Weijia; Yao, Chun] Sacred Heart Univ, Jack Welch Coll Business & Technol, Dept Finance, 5151 Pk Ave, Fairfield, CT 06825 USA'

# %%
df['Addresses'].head()
# Out:
# index
# 0    [Vanini, Paolo] Univ Basel, Basel, Switzerland...
# 1    [Baiardi, Anna] Erasmus Univ, Erasmus Sch Econ...
# 2    [Peng, Weijia; Yao, Chun] Sacred Heart Univ, J...
# 3    [Brewer, Dylan] Georgia Inst Technol, Sch Econ...
# 4    [Kynigakis, Iason] Univ Coll Dublin, Smurfit G...
# Name: Addresses, dtype: object

# %%
# remove duplicates in Addresses new
df['Addresses new'] = df['Addresses new'].apply(lambda x: list(set(x)))

# %%
# caplitalize the first letter of each word in Addresses new
df['Addresses new'] = df['Addresses new'].apply(lambda x: [i.capitalize() for i in x])

# %%
# read JavaScript file content to get the name of countries
# echarts map world.js

with open('world.js', 'r', encoding='utf-8') as file:
    js_content = file.read()

# find the content after 'features":'
pattern = js_content.split('features":')[1]
# split by ,"UTF8Encoding
pattern = pattern.split(',"UTF8Encoding')[0]
pattern = eval(pattern)
print(pattern)
print(type(pattern))

# get all the content after properties and name
countries = []
for i in pattern:
    countries.append(i['properties']['name'])

print(countries)
print(len(countries))
# Out:
# [{'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': ['@@ྡǪ˵ͬࡗȲ́ЬTҼͯrđ͆ࡓӀއึ๚Ƒފࣀ̪۠źҚӘʔބ®\x96̑ڢyෲׁ\x9c൭ʗӥʘ࢙п֥¿ՙॣक'], 'encodeOffsets': [[32039, -22939]]}, 'properties': {'name': 'Zimbabwe', 'full_name': 'Republic of Zimbabwe', 'iso_a2': 'ZW', 'iso_a3': 'ZWE', 'iso_n3': 716}}, {'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': ['@@ރ\xadӗʓŹҙ̩۟މࢿ๙ƒѳɴ\u0b11Ļ\u0af7\u0b46½ᩘဠZFᄰͲɑZʋވǤ¼Ή֪ɡڢÙ˰͖ΐխ۶ʓԐ܍ҒĶȄǃjંʹəΟÎֱڂɚࡢȵ\u0adaкت༔ʖʂ\u0379མڻخ३ͳ˷QਁɔȡЫʁ̏߭ҀΡ᠁ࠑƐշ'], 'encodeOffsets': [[31126, -16018]]}, 'properties': {'name': 'Zambia', 'full_name': 'Republic of Zambia', 'iso_a2': 'ZM', 'iso_a3': 'ZMB', 'iso_n3': 894}}, {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'coordinates': [['@@ُ̕ġՙᜯࡣֳӳ֭C\u09dbөोŃԳѭࢃǩѣúɋӌʝචɹʚŢड़̬ˊv֜ȒƂмǇᚾ¹Δˋࡺ৮ܴΦើΒजጉ'], ['@@ؼëڕȟ\u0379ǶϔĖ']], 'encodeOffsets': [[[54360, 17048]], [[55054, 12941]]]}, 'properties': {'name': 'Yemen', 'full_name': 'Republic of Yemen', 'iso_a2': 'YE', 'iso_a3': 'YEM', 'iso_n3': 887}}, {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'coordinates': [['@@\x9d̥ƙ˾Ǹh'], ['@@ڵҹЙªġԝӵϟ̥ࠇ݄ࡧŅǙᏚጱԔᎡȍਗǱ͛ࠡԭث˓ɉɚ·ɕ˻ÆŶƛʗF˒Ƴǅɍϫ̦̈֍չψ˴ԓࢭ٣́\x81˄୰փΔΦļǎ̈́\u05eeà΄Ǎʿ۸Ңª^ɘࣾΔČࣖɱׂǀӠŒҨХҠȘȮةϘŻϲ\u0b59\u0bda\x80ȸੇռŞ̶Ҵ³˸Ͳһ\u03a2ǺǦЛʤϹȽѿǐɅ̾ĊΒʍI҅נ̸̀іʫ̂˔Ԭȕ૬ڰӊΡ\u07beťȕɷĨѭસЃ']], 'encodeOffsets': [[[106562, 10641]], [[110564, 22025]]]}, 'properties': {'name': 'Vietnam', 'full_name': 'Socialist Republic of Vietnam', 'iso_a2': 'VN', 'iso_a3': 'VNM', 'iso_n3': 704}}, {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'coordinates': [['@@ËȳСĂҮŲ'], ['@@Ƙʧܳ׳̮҃ڙʵdЗəɳղإŚɃͯΏ෭ѣŧΥЙֵ̎]٣̆ӊׁƦ࣭ւù\x97ɋӛȋǑ͵\u0a65۵ǩʘ֓ǻѻϦ˫খկͺҢԺҙ̼ࣼජ࿏³םۤགྷâϹЮèٚͿ۔ӏî֪ൢؚۦ՜ǐ\u0557ʕ̦ދѥۻв٣͆ĦǄҜω۞tδඐєЙΌʂʖ̼וڮ¡ήɫɒ֗ཤŞͪ̿؈ƿ୮θӇŎ\u139aĘࢅǫƢЍǆŨȖΗȴǊ˺˿Ůɚڞ҃ϣ̷ٕE˄ƽઌŜ']], 'encodeOffsets': [[[-65381, 11399]], [[-61457, 8755]]]}, 'properties': {'name': 'Venezuela', 'full_name': 'Bolivarian Republic of Venezuela', 'iso_a2': 'VE', 'iso_a3': 'VEN', 'iso_n3': 862}}, {'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': ['@@Q@@PRO'], 'encodeOffsets': [[12738, 42904]]}, 'properties': {'name': 'Vatican City', 'full_name': 'Vatican City State', 'iso_a2': 'VA', 'iso_a3': 'VAT', 'iso_n3': 336}}, {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'coordinates': [['@@Ä˥ɠȆfէ˯§ŃȎÁٜƬƹ'], ['@@Τ̓͗ėȿ֜Ǵǯ'], ['@@̯ĜȠŮŐɉ'], ['@@âɋ̯ôʎƘ'], ['@@ȥ_ˠƚùŹ'], ['@@ŧéċɺȴǏ'], ['@@̇Ì|Ȓˌʝ']], 'encodeOffsets': [[[170748, -15182]], [[171431, -16482]], [[172336, -16728]], [[172489, -17963]], [[171942, -15806]], [[173560, -20009]], [[173399, -19394]]]}, 'properties': {'name': 'Vanuatu', 'full_name': 'Republic of Vanuatu', 'iso_a2': 'VU', 'iso_a3': 'VUT', 'iso_n3': 548}}, {'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': ['@@ʂïࡹկ\u09ca͟ɬΘѮџߚǷ்փ؟ðӱŪ͊˴̋ˀׁ̙ͅĢçӍէ}˼ÝёҭࢋÑËȽٲʏǾ\u05f9ӹ\u088fਥƨì՜࠱Ʉ༉ޠ\u0a7fۆӣरແʲĕۀ୩ӊοų˔ˡϏǂࣃՋ®ӿ\u0893¸AᶢᓢҼᏠউࠚݷបȈݮ۳ʠĪùࠡЪUǰۅਐd̘ғʀ\x83Ӧڬຘۖ'], 'encodeOffsets': [[72650, 43263]]}, 'properties': {'name': 'Uzbekistan', 'full_name': 'Republic of Uzbekistan', 'iso_a2': 'UZ', 'iso_a3': 'UZB', 'iso_n3': 860}}, {'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': ['@@Αՙभҫଇ\x82ޝϖօqԝِØҌɬǸğжӾኆٶæڎ֝\x92ʩͶȔ\u0efa\u09e5\u0558֯ͿηƊӓ'], 'encodeOffsets': [[-54651, -34552]]}, 'properties': {'name': 'Uruguay', 'full_name': 'Eastern Republic of Uruguay', 'iso_a2': 'UY', 'iso_a3': 'URY', 'iso_n3': 858}}, {'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': ['@@ƯŌƆLjŗ'], 'encodeOffsets': [[162115, 6978]]}, 'properties': {'name': 'Micronesia', 'full_name': 'Federated States of Micronesia', 'iso_a2': 'FM', 'iso_a3': 'FSM', 'iso_n3': 583}}, {'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': ['@@ʖwƃ\x95ǙòÈc'], 'encodeOffsets': [[175209, 7310]]}, 'properties': {'name': 'Marshall Islands', 'full_name': 'Republic of the Marshall Islands', 'iso_a2': 'MH', 'iso_a3': 'MHL', 'iso_n3': 584}}, {'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': ['@@\x8dèĞ¦Ïō'], 'encodeOffsets': [[149250, 15497]]}, 'properties': {'name': 'Northern Mariana Islands', 'full_name': 'Commonwealth of the Northern Mariana Islands (USA)', 'iso_a2': ...
# <class 'list'>
# ['Zimbabwe', 'Zambia', 'Yemen', 'Vietnam', 'Venezuela', 'Vatican City', 'Vanuatu', 'Uzbekistan', 'Uruguay', 'Micronesia', 'Marshall Islands', 'Northern Mariana Islands', 'United States Virgin Islands', 'Guam', 'American Samoa', 'Puerto Rico', 'United States', 'South Georgia and the South Sandwich Islands', 'British Indian Ocean Territory', 'Saint Helena', 'Pitcairn Islands', 'Anguilla', 'Falkland Islands', 'Cayman Islands', 'Bermuda', 'British Virgin Islands', 'Turks and Caicos Islands', 'Montserrat', 'Jersey', 'Guernsey', 'Isle of Man', 'United Kingdom', 'United Arab Emirates', 'Ukraine', 'Uganda', 'Turkmenistan', 'Turkey', 'Tunisia', 'Trinidad and Tobago', 'Tonga', 'Togo', 'East Timor', 'Thailand', 'Tanzania', 'Tajikistan', 'Syria', 'Switzerland', 'Sweden', 'Eswatini', 'Suriname', 'South Sudan', 'Sudan', 'Sri Lanka', 'Spain', 'South Korea', 'South Africa', 'Somalia', 'Somaliland', 'Solomon Islands', 'Slovakia', 'Slovenia', 'Singapore', 'Sierra Leone', 'Seychelles', 'Serbia', 'Senegal', 'Saudi Arabia', 'São Tomé and Príncipe', 'San Marino', 'Samoa', 'Saint Vincent and the Grenadines', 'Saint Lucia', 'Saint Kitts and Nevis', 'Rwanda', 'Russia', 'Romania', 'Qatar', 'Portugal', 'Poland', 'Philippines', 'Peru', 'Paraguay', 'Papua New Guinea', 'Panama', 'Palau', 'Pakistan', 'Oman', 'Norway', 'North Korea', 'Nigeria', 'Niger', 'Nicaragua', 'New Zealand', 'Niue', 'Cook Islands', 'Netherlands', 'Aruba', 'Curaçao', 'Nepal', 'Nauru', 'Namibia', 'Mozambique', 'Morocco', 'Western Sahara', 'Montenegro', 'Mongolia', 'Moldova', 'Monaco', 'Mexico', 'Mauritius', 'Mauritania', 'Malta', 'Mali', 'Maldives', 'Malaysia', 'Malawi', 'Madagascar', 'North Macedonia', 'Luxembourg', 'Lithuania', 'Liechtenstein', 'Libya', 'Liberia', 'Lesotho', 'Lebanon', 'Latvia', 'Laos', 'Kyrgyzstan', 'Kuwait', 'Kosovo', 'Kiribati', 'Kenya', 'Kazakhstan', 'Jordan', 'Japan', 'Jamaica', 'Italy', 'Israel', 'Palestine', 'Ireland', 'Iraq', 'Iran', 'Indonesia', 'India', 'Iceland', 'Hungary', 'Honduras', 'Haiti', 'Guyana', 'Guinea-Bissau', 'Guinea', 'Guatemala', 'Grenada', 'Greece', 'Ghana', 'Germany', 'Georgia', 'Gambia', 'Gabon', 'France', 'Saint Pierre and Miquelon', 'Wallis and Futuna', 'Saint Martin (French part)', 'Saint Barthélemy', 'French Polynesia', 'New Caledonia', 'French Southern and Antarctic Lands', 'Åland Islands', 'Finland', 'Fiji', 'Ethiopia', 'Estonia', 'Eritrea', 'Equatorial Guinea', 'El Salvador', 'Egypt', 'Ecuador', 'Dominican Republic', 'Dominica', 'United States Minor Outlying Islands', 'Djibouti', 'Greenland', 'Faroe Islands', 'Denmark', 'Czechia', 'Northern Cyprus', 'Cyprus', 'Cuba', 'Croatia', 'Ivory Coast', 'Costa Rica', 'Democratic Republic of the Congo', 'Republic of the Congo', 'Comoros', 'Colombia', 'China', 'Chile', 'Chad', 'Central African Republic', 'Cape Verde', 'Canada', 'Cameroon', 'Cambodia', 'Myanmar', 'Burundi', 'Burkina Faso', 'Bulgaria', 'Brunei', 'Brazil', 'Botswana', 'Bosnia and Herzegovina', 'Bolivia', 'Bhutan', 'Benin', 'Belize', 'Belgium', 'Belarus', 'Barbados', 'Bangladesh', 'Bahrain', 'Bahamas', 'Azerbaijan', 'Austria', 'Australia', 'Christmas Island', 'Heard Island and McDonald Islands', 'Norfolk Island', 'Ashmore and Cartier Islands', 'Armenia', 'Argentina', 'Antigua and Barbuda', 'Angola', 'Andorra', 'Algeria', 'Albania', 'Afghanistan', 'Siachen Glacier', 'Sint Maarten (Dutch part)', 'Tuvalu']
# 239

# %%
'''
England
Scotland
Gibraltar
United Kingdom

Taiwan
China

Korea
South Korea

Timor-leste 
East Timor

Congo
Democratic Republic of the Congo

Usa
United States

Macedonia
North Macedonia

'''

# replace the name
def replace_address_in_list(address_list):
    replacements = {
        'England': 'United Kingdom',
        'Scotland': 'United Kingdom',
        'Gibraltar': 'United Kingdom',
        'Taiwan': 'China',
        'Korea': 'South Korea',
        'Timor-leste': 'East Timor',
        'Congo': 'Democratic Republic of the Congo',
        'Usa': 'United States',
        'Macedonia': 'North Macedonia'
    }
    
    updated_list = []
    for address in address_list:
        for old, new in replacements.items():
            if old in address:
                address = address.replace(old, new)
        updated_list.append(address)
    
    return updated_list

df['Addresses new'] = df['Addresses new'].apply(replace_address_in_list)

# print invalid countries
invalid_countries = []
for i in df['Addresses new'].values:
    for j in i:
        if j not in countries: 
            invalid_countries.append(j)
invalid_countries = set(invalid_countries)

# %%
import pycountry

# check if the country is valid
def is_valid_country(country):
    try:
        return pycountry.countries.lookup(country) is not None
        return True
    except LookupError:
        return False
    
for i in invalid_countries:
    if is_valid_country(i) == True and len(i) > 2:
        print(i)
# Out:
# Ben
# Guy
# Sen
# Pan
# Ken
# Hun
# Nga
# Vir
# Nam
# Mar
# Per
# Can

# %%
# filter out invalid countries
df['Addresses new'] = df['Addresses new'].apply(lambda x: [i for i in x if i in countries])

# %%
# unique Addresses new and count the number of each address
addresses = df['Addresses new'].explode().value_counts()
addresses
# Out:
# United States     6236
# China             2992
# United Kingdom    1867
# Germany           1605
# Canada             953
#                   ...
# Angola               1
# Eswatini             1
# Guatemala            1
# Bahamas              1
# Grenada              1
# Name: Addresses new, Length: 138, dtype: int64

# %%
# any publications without Addresses new?
print(f"Number of publications without Addresses new: {df['Addresses new'].apply(len).eq(0).sum()}")
# Out:
# Number of publications without Addresses new: 596

# %% [markdown]
# # 7. deal Affiliations

# %%
# any publications without Affiliations
print(f"Number of publications without Affiliations: {df['Affiliations'].isnull().sum()}")
# Out:
# Number of publications without Affiliations: 1039

# %%
# split the Affiliations by ;
df['Affiliations new'] = df['Affiliations'].str.split(';')
# fill missing values with empty list
df['Affiliations new'] = df['Affiliations new'].apply(lambda x: [] if type(x) != list else x)
# remove leading and trailing spaces
df['Affiliations new'] = df['Affiliations new'].apply(lambda x: [i.strip() for i in x])

# %%
# unique Affiliations new and count the number of each affiliation
affiliations = df['Affiliations new'].explode().value_counts()
affiliations
# Out:
# University of California System         690
# Chinese Academy of Sciences             464
# University of London                    442
# Harvard University                      389
# State University System of Florida      343
#                                        ...
# Guangzhou Railway Polytechnic             1
# Philips Research                          1
# Antalya Training & Research Hospital      1
# City Hospital Ankara                      1
# Osaka Institute of Technology             1
# Name: Affiliations new, Length: 5089, dtype: int64

# %% [markdown]
# # 8. preprocess abstract

# %%
# any publications without Abstract
print(f"Number of publications without Abstract: {df['Abstract'].isnull().sum()}")
# Out:
# Number of publications without Abstract: 116

# %%
# fill missing Abstract with empty string
df['Abstract'] = df['Abstract'].fillna('')

# %%
# revert abbreviation to full name in Abstract
df['Abstract new'] = df['Abstract'].apply(lambda x: fix(x))

# %%
# lower case
df['Abstract new'] = df['Abstract new'].str.lower()

# %%
# delete all the puntuation in Abstract
df['Abstract new'] = df['Abstract new'].str.replace('[^\w\s]', '')
# Out:
# /var/folders/7l/twwtwnnx4lx0j2hh0ytd0kqh0000gn/T/ipykernel_2751/1662566092.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Abstract new'] = df['Abstract new'].str.replace('[^\w\s]', '')

# %%
from nltk.tokenize import word_tokenize

df['Abstract new'] = df['Abstract new'].apply(lambda x: word_tokenize(x) if type(x) == str else [])

# %%
# show first 5 Abstract and Abstract new
df[['Abstract', 'Abstract new']].head()
# Out:
#                                                 Abstract  \
# index
# 0      Online banking fraud occurs whenever a crimina...
# 1      This paper undertakes a replication in a wide ...
# 2      In this paper, we develop new latent risk meas...
# 3      We study approaches for adjusting machine lear...
# 4      This study evaluates the benefits of integrati...
#
#                                             Abstract new
# index
# 0      [online, banking, fraud, occurs, whenever, a, ...
# 1      [this, paper, undertakes, a, replication, in, ...
# 2      [in, this, paper, we, develop, new, latent, ri...
# 3      [we, study, approaches, for, adjusting, machin...
# 4      [this, study, evaluates, the, benefits, of, in...

# %%
# lemmaize Abstract new
lemmatized_abstract = []

for abstract in df['Abstract new'].values:
    lemmatized_list = []
    for word in abstract:
        lemmatized_list.append(lemmatizer.lemmatize(word))
    lemmatized_abstract.append(lemmatized_list)

df['Abstract lemmatized'] = lemmatized_abstract

# %%
# remove stopwords
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

df['Abstract lemmatized'] = df['Abstract lemmatized'].apply(lambda x: [i for i in x if i not in stop_words])

# %%
# show the first row Abstract lemmatized
df['Abstract lemmatized'].head(1)
# Out:
# index
# 0    [online, banking, fraud, occurs, whenever, cri...
# Name: Abstract lemmatized, dtype: object

# %%
df.columns
# Out:
# Index(['Publication Type', 'Authors', 'Book Authors', 'Book Editors',
#        'Book Group Authors', 'Author Full Names', 'Book Author Full Names',
#        'Group Authors', 'Article Title', 'Source Title', 'Book Series Title',
#        'Book Series Subtitle', 'Language', 'Document Type', 'Conference Title',
#        'Conference Date', 'Conference Location', 'Conference Sponsor',
#        'Conference Host', 'Author Keywords', 'Keywords Plus', 'Abstract',
#        'Addresses', 'Affiliations', 'Reprint Addresses', 'Email Addresses',
#        'Researcher Ids', 'ORCIDs', 'Funding Orgs', 'Funding Name Preferred',
#        'Funding Text', 'Cited References', 'Cited Reference Count',
#        'Times Cited, WoS Core', 'Times Cited, All Databases',
#        '180 Day Usage Count', 'Since 2013 Usage Count', 'Publisher',
#        'Publisher City', 'Publisher Address', 'ISSN', 'eISSN', 'ISBN',
#        'Journal Abbreviation', 'Journal ISO Abbreviation', 'Publication Date',
#        'Publication Year', 'Volume', 'Issue', 'Part Number', 'Supplement',
#        'Special Issue', 'Meeting Abstract', 'Start Page', 'End Page',
#        'Article Number', 'DOI', 'DOI Link', 'Book DOI', 'Early Access Date',
#        'Number of Pages', 'WoS Categories', 'Web of Science Index',
#        'Research Areas', 'IDS Number', 'Pubmed Id', 'Open Access Designations',
#        'Highly Cited Status', 'Hot Paper Status', 'Date of Export',
#        'UT (Unique WOS ID)', 'Web of Science Record', 'Decade', 'Group',
#        'WoS Categories new', 'Research Areas new', 'Keywords Plus new',
#        'Keywords Plus lemmatized', 'Author Keywords new',
#        'Author Keywords lemmatized', 'All Keywords', 'Addresses new',
#        'Affiliations new', 'Abstract new', 'Abstract lemmatized'],
#       dtype='object')

# %%
# ['Article Title', 'Source Title', 'Language', 'Times Cited, All Databases', 'Highly Cited Status', 'Hot Paper Status', 'Publication Year', 'Decade', 'Group', 'WoS Categories new', 'Research Areas new', 'Keywords Plus lemmatized', 'Author Keywords lemmatized', 'All Keywords', 'Addresses new', 'Affiliations new', 'Abstract lemmatized']
# save the DataFrame as a csv file with the following columns
df[['Article Title', 'Source Title', 'Language', 'Times Cited, All Databases', 'Highly Cited Status', 'Hot Paper Status', 'Publication Year', 'Decade', 'Group', 'WoS Categories new', 'Research Areas new', 'Keywords Plus lemmatized', 'Author Keywords lemmatized', 'All Keywords', 'Addresses new', 'Affiliations new', 'Abstract lemmatized']].to_csv('preprocessed_data.csv', index=False)
